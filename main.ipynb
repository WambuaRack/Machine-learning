# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ![Screenshot 2024-03-11 113717.png](<attachment:Screenshot 2024-03-11 113717.png>)

# %% [markdown]
# ![Screenshot 2024-03-11 113859.png](<attachment:Screenshot 2024-03-11 113859.png>)

# %% [markdown]
# upervised learning
#
# unsupervised
# reinforced - based on gifts and penalties

# %% [markdown]
# ![Screenshot 2024-03-11 114045.png](<attachment:Screenshot 2024-03-11 114045.png>)
